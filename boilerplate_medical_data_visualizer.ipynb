# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Cargar el conjunto de datos
df = pd.read_csv('/content/medical_examination.csv')

# %%
# Agregar la columna 'overweight'
df['IMC'] = df['weight'] / (df['height'] / 100) ** 2
df['overweight'] = (df['IMC'] > 25).astype(int)

# %%
# Normalizar los datos
df['cholesterol'] = (df['cholesterol'] > 1).astype(int)
df['gluc'] = (df['gluc'] > 1).astype(int)

# %%
# Convertir los datos a formato largo
df_long = pd.melt(df, id_vars=["cardio"], value_vars=["cholesterol", "gluc", "alco", "active", "smoke"])

# %%
# Personalizar el gráfico
g.set_axis_labels("Variables Categóricas", "Recuento")
g.set_titles("{col_name} Cardio")
g.set(ylim=(0, max(df_long['value'].value_counts()) + 1000))
g.legend.set_title("Valor")
plt.suptitle("Recuentos de valores de características categóricas", y=1.02)

# Guardar el gráfico
plt.savefig("Figure_1.png")
plt.show()

# %%
# Crear un gráfico catplot
sns.set(style="whitegrid")
g = sns.catplot(data=df_long, x="variable", hue="value", col="cardio", kind="count", height=5, aspect=0.8)
